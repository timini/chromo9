# %%
from unipath import Path

# %%
test_file = Path('./split_files/xx00').read_file()

# %%
from Bio import GenBank

# %%
gbrecord = GenBank.read(open('./split_files/xx00'))

# %%
test_keys = gbrecord.__dict__.keys()

# %%
for p in Path('./split_files/').listdir():
    try:
        gbr = GenBank.read(open(p))
        assert gbr.__dict__.keys() == test_keys
        print gbr.accession
    except:
        print p
# Out:
# ['AB009589']
# ['AB014887']
# ['AB019534']
# ['AB038490']
# ['AB046409']
# ['AB051625']
# ['AB051627']
# ['AB060808']
# ['AB065490']
# ['AB065491']
# ['AB065492']
# ['AF286717']
# ['EU286280']
# ['EU363227']
# ['EU363228']
# ['EU363229']
# ['EU363230']
# ['EU363231']
# ['EU377675']
# ['EU442892']
# ['EU534205']
# ['EU534206']
# ['AF288155']
# ['EU551754']
# ['EU707567']
# ['EU924174']
# ['FJ009674']
# ['FJ213840']
# ['FJ213841']
# ['FJ483546']
# ['FJ599810']
# ['FJ638611']
# ['FJ775180']
# ['AF295775']
# ['FJ851690']
# ['FJ851691']
# ['FJ851692']
# ['FJ851693']
# ['FJ851694']
# ['FJ851695']
# ['FJ998203']
# ['FN598479']
# ['FN598480']
# ['FN598481']
# ['AF295776']
# ['FN598482']
# ['FN908798']
# ['FN908799']
# ['FN908800']
# ['FN908801']
# ['FN908802']
# ['FN908803']
# ['FN908804']
# ['FN908805']
# ['FN908806']
# ['AF295777']
# ['FN908807']
# ['FN984793']
# ['FN984794']
# ['GQ175288']
# ['GQ175289']
# ['GQ175290']
# ['GQ175291']
# ['GQ229192']
# ['GQ229193']
# ['GQ355273']
# ...

# %%
gbrecord.accession
# Out:
# ['AB009589']

# %%
# Out:
# {'key': '/organism=', 'value': '"Homo sapiens"'}
